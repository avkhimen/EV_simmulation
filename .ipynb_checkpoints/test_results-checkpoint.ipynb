# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
name = 'test3'
averages = np.load(name + '_average_list.npy')
rewards = np.load(name + '_reward_list.npy')
Q = np.load(name + '_Q.npy')

# %%
print(averages.shape)
print(averages)
plt.plot(averages)
# Out:
# (10,)
# [9704.87549908 9659.49174908 9740.62883242 9684.29508242 9745.29133242
#  9714.37341575 9659.06383242 9699.12383242 9647.45716575 9708.95633242]

# %%
print(rewards.shape)
print(rewards)
plt.plot(rewards)
# Out:
# (10,)
# [ 1.93318974 -4.06046271  1.95629215 -4.06343732  1.96878798  1.96194429
#  -4.04201307 -4.03782174 -4.04166946 -4.04542037]

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[0])
        l.append(max_action)
    l_2.append(np.array(l))
l = np.array(l_2)
print(l)
a = l[0].copy()
l[0] = l[4]
l[4] = a
b = l[1].copy()
l[1] = l[3]
l[3] = b
print('------------------------------------------------')
print(l)
fig, ax = plt.subplots(figsize=(35, 8))
im = ax.imshow(l)
fig.colorbar(im)
# Out:
# [[1 2 2 0 1 1 0 1 2 2 1 0 1 2 0 0 0 1 1 0 2 0 2 0]
#  [0 2 1 1 2 2 1 1 0 2 0 1 1 0 0 1 2 1 0 2 2 0 2 0]
#  [1 0 1 1 2 1 1 2 1 2 1 0 1 2 0 1 2 0 0 1 0 0 2 0]
#  [2 1 1 1 1 2 2 2 2 1 2 1 0 1 0 2 0 0 2 1 0 1 2 0]
#  [1 1 2 1 2 1 1 1 0 0 0 2 1 0 2 2 1 1 1 1 1 0 2 0]]
# ------------------------------------------------
# [[1 1 2 1 2 1 1 1 0 0 0 2 1 0 2 2 1 1 1 1 1 0 2 0]
#  [2 1 1 1 1 2 2 2 2 1 2 1 0 1 0 2 0 0 2 1 0 1 2 0]
#  [1 0 1 1 2 1 1 2 1 2 1 0 1 2 0 1 2 0 0 1 0 0 2 0]
#  [0 2 1 1 2 2 1 1 0 2 0 1 1 0 0 1 2 1 0 2 2 0 2 0]
#  [1 2 2 0 1 1 0 1 2 2 1 0 1 2 0 0 0 1 1 0 2 0 2 0]]

# %%
Q
# Out:
# array([[[[-0.01010027, -0.01      , -0.01      ],
#          [-0.01      , -0.01      , -0.02000027],
#          [-0.01010027, -0.01      , -0.01      ]],
#
#         [[-0.01035606, -0.01063386, -0.0101704 ],
#          [-0.01039639, -0.02035859, -0.0100267 ],
#          [-0.01014157, -0.01024534, -0.01028053]],
#
#         [[-0.01063914, -0.01051802, -0.01021475],
#          [-0.02032457, -0.01017829, -0.01031272],
#          [-0.01021857, -0.01000122, -0.01035676]],
#
#         ...,
#
#         [[ 0.05739262,  0.        ,  0.        ],
#          [ 0.05774014,  0.        ,  0.01938975],
#          [ 0.0585485 ,  0.        ,  0.        ]],
#
#         [[ 0.        ,  0.        ,  0.05686486],
#          [ 0.03898651,  0.        , -0.02100155],
#          [ 0.        , -0.04043138,  0.03900443]],
#
#         [[ 0.        ,  0.        , -0.00189537],
#          [-0.02146605,  0.        , -0.02126708],
#          [-0.0405542 , -0.04042013, -0.04037822]]],
#
#
#        [[[-0.01      , -0.01010344, -0.01      ],
#          [-0.02000027, -0.01      , -0.01      ],
#          [-0.01      , -0.01010344, -0.01      ]],
#
#         [[-0.01063386, -0.01035606, -0.0101704 ],
#          [-0.01034381, -0.02004465, -0.01039639],
#          [-0.01027872, -0.01014157, -0.01024354]],
#
#         [[-0.01063914, -0.01021475, -0.01051802],
#          [-0.01017829, -0.0099976 , -0.02063653],
#          [-0.01035676, -0.01021857, -0.01000122]],
#
#         ...,
#
#         [[ 0.0573926 ,  0.        ,  0.        ],
#          [ 0.        ,  0.01938975,  0.05774014],
#          [ 0.        ,  0.05854848,  0.        ]],
#
#         [[ 0.        ,  0.        ,  0.05686486],
#          [-0.02100155,  0.        ,  0.0389842 ],
#          [ 0.        , -0.04043138,  0.03900443]],
#
#         [[ 0.        , -0.00189537,  0.        ],
#          [-0.02149579, -0.02063566,  0.        ],
#          [-0.04042013, -0.04037822, -0.0405542 ]]],
#
#
#        [[[-0.01010344, -0.01      , -0.01      ],
#          [-0.01      , -0.01      , -0.02000027],
#          [-0.01      , -0.01010344, -0.01      ]],
#
#         [[-0.0101704 , -0.01035606, -0.01063386],
#          [-0.01039639, -0.01034381, -0.02004465],
#          [-0.01014157, -0.01028053, -0.01024534]],
#
#         [[-0.01051958, -0.01021475, -0.01064069],
#          [-0.02022374, -0.01017829, -0.01031272],
#          [-0.01035831, -0.01021857, -0.01000122]],
#
#         ...,
#
#         [[ 0.05739262,  0.        ,  0.        ],
#          [ 0.01951953,  0.01938975,  0.03860904],
#          [ 0.        ,  0.        ,  0.0585485 ]],
#
#         [[ 0.        ,  0.        ,  0.05686486],
#          [ 0.03898651, -0.02100155,  0.        ],
#          [ 0.03900443, -0.04043138,  0.        ]],
#
#         [[ 0.01961944, -0.04051669,  0.01958788],
#          [-0.02146605,  0.        , -0.02126708],
#          [-0.04037822, -0.04042013, -0.0405542 ]]],
#
#
#        [[[-0.01      , -0.0200024 ,  0.        ],
#          [-0.02000027, -0.01      , -0.01      ],
#          [-0.01010344, -0.01      , -0.01      ]],
#
#         [[-0.01035606,  0.        , -0.02070255],
#          [-0.02004465, -0.01039639, -0.01034381],
#          [-0.01014157, -0.01024354, -0.01027872]],
#
#         [[-0.01051802, -0.01021475, -0.01063914],
#          [-0.02063653, -0.01017829, -0.0099976 ],
#          [-0.01021857, -0.01035676, -0.01000122]],
#
#         ...,
#
#         [[ 0.        ,  0.05720036,  0.        ],
#          [ 0.        ,  0.        ,  0.07655272],
#          [ 0.        ,  0.        ,  0.05835817]],
#
#         [[ 0.        ,  0.        ,  0.0574459 ],
#          [ 0.        , -0.00117642,  0.01956707],
#          [-0.04043138,  0.03900443,  0.        ]],
#
#         [[ 0.        ,  0.        , -0.00179537],
#          [ 0.01956292, -0.04063437, -0.02146605],
#          [-0.0405542 , -0.04042013, -0.04037822]]],
#
#
#        [[[-0.01010344, -0.01      , -0.01      ],
#          [-0.01      , -0.01      , -0.02000027],
#          [-0.01010344, -0.01      , -0.01      ]],
#
#         [[-0.01035606, -0.0101704 , -0.01063386],
#          [-0.01039639, -0.02004465, -0.01034381],
#          [-0.02042307,  0.        , -0.01014157]],
#
#         [[-0.01063914, -0.01051802, -0.01021475],
#          [-0.01017829, -0.01031272, -0.02032457],
#          [-0.01035676, -0.01000122, -0.01021857]],
#
#         ...,
#
#         [[ 0.05739262,  0.        ,  0.        ],
#          [ 0.        ,  0.05784936,  0.01928185],
#          [ 0.0585485 ,  0.        ,  0.        ]],
#
#         [[ 0.        ,  0.        ,  0.05686486],
#          [-0.02100155,  0.        ,  0.03898651],
#          [ 0.03900443,  0.        , -0.04043138]],
#
#         [[ 0.        ,  0.        , -0.00189537],
#          [-0.02126708, -0.02146605,  0.        ],
#          [-0.0405542 , -0.04037822, -0.04042013]]]])

# %%
r1 = np.load(str(3) + '_1000iter_reward_list.npy')
r2 = np.load(str(4) + '_1000iter_reward_list.npy')
r3 = np.load(str(5) + '_1000iter_reward_list.npy')
r = (r1+r2+r3)/3
plt.plot(r)

# %%
r = np.load('test_2_average_list.npy')
comb = []
run_sum = 0
average_over = 10
for ii, item in enumerate(r):
    run_sum += item
    if ii % average_over == 0:
        comb.append(run_sum/average_over)
        run_sum = 0

# %%
plt.plot(comb[1:])

# %%
comb
# Out:
# [0.09631932684663459,
#  -0.7490521264357798,
#  -1.0552022801708767,
#  -1.3435259972718425,
#  -1.349494700507801,
#  -2.2411297326278703,
#  -1.9498193422572534,
#  -2.2451016468320266,
#  -1.0456424366912558,
#  -1.648223743266756,
#  -1.34343384354866,
#  -2.2458433130867412,
#  -1.0481602438763793,
#  -2.543070657027824,
#  -2.2476794674273477,
#  -1.9473442055457924,
#  -1.0459840899154658,
#  -1.6436540500179633,
#  -1.9429887400573798,
#  -0.7452891088738611,
#  -1.942828239884917,
#  -1.6471423849041482,
#  -2.2475360768472004,
#  -1.3512823768798765,
#  -1.649349207501204,
#  -1.3518966289436498,
#  -0.15336869799889238,
#  -0.4524427880581718,
#  -1.0461850828730181,
#  -1.3484397801608445,
#  -1.3531979409366133,
#  -0.4498625637054131,
#  -1.0533741552958957,
#  -1.648214726243804,
#  -1.6523600936468246,
#  -1.0561735176272855,
#  -1.3526328873890892,
#  -1.353102026745302,
#  -0.7575804670293101,
#  0.7343722944867288,
#  0.43451256214996514,
#  0.13675994211104453,
#  0.12906206922964575,
#  0.13770647004916375,
#  -1.3567306650905937,
#  -1.3548281872986743,
#  -1.9595648396021716,
#  -1.0552554832481902,
#  -0.4628950131335626,
#  0.131677840867138]

# %%
def compare_Q(Q1, Q2):
    l_2 = []
    for row in Q1:
        l = []
        for column in row:
            max_action = np.argmax(column[0])
            l.append(max_action)
        l_2.append(np.array(l))
    l_Q1 = np.array(l_2)
    
    l_2 = []
    for row in Q2:
        l = []
        for column in row:
            max_action = np.argmax(column[0])
            l.append(max_action)
        l_2.append(np.array(l))
    l_Q2 = np.array(l_2)
    
    return np.count_nonzero(l_Q1-l_Q2)

# %%
a = np.array([1, 2, 2,])
b = np.array([1, 1, 3])
a - b
# Out:
# array([ 0,  1, -1])

# %%
np.count_nonzero(a-b)
# Out:
# 2

# %%
print(compare_Q(Q, Q))
# Out:
# 0

# %%
Q_change_list = np.load('test3_Q_change_list.npy')

# %%
Q_change_list
# Out:
# array([ 0,  0,  0,  0, 60, 64,  0,  0, 80,  0])

# %%
total = np.load('test3_total_list.npy')

# %%
total
# Out:
# array([10353.26076923, 10243.53076923, 10166.37076923, 10298.64076923,
#        10019.11076923, 10084.06076923, 10064.87076923, 10011.90076923,
#         9681.36076923, 10149.94076923])

# %%
PAR = np.load('test3_PAR_list.npy')

# %%
PAR
# Out:
# array([1.06681026, 1.06046271, 1.04370785, 1.06343732, 1.03121202,
#        1.03805571, 1.04201307, 1.03782174, 1.04166946, 1.04542037])

# %%
plt.plot(PAR)
